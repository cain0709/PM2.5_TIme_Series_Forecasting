# %%
import os
import gc
from tqdm import tqdm
import glob
import random
import pandas as pd
import numpy as np
import sklearn
import math
import matplotlib.pyplot as plt
import prophet
import pdb
import datetime
from scipy import interpolate
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchinfo import summary
from torch.utils.data import DataLoader, Dataset

# %%
print('pandas ver : ' + pd.__version__)
print('numpy ver : ' + np.__version__)
print('sklearn ver : ' + sklearn.__version__)
print('prophet ver :' + prophet.__version__)
# Out:
# pandas ver : 1.5.3
# numpy ver : 1.23.2
# sklearn ver : 1.2.2
# prophet ver :1.13.1

# %%
INPUT_TIMESTEP = 48
OUTPUT_TIMESTEP = 72
TEACHER_FORCING_RATIO = 0.5
EPOCHS = 50
LR = 1e-3
BS = 64
SEED = 42
MODEL_NAME ='LSTM_Seq2Seq'
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
seed_everything(SEED) # Seed 고정

# %%
device = torch.device('cpu') if torch.backends.mps.is_available() else torch.device('cpu')
torch.autograd.set_detect_anomaly(False)
print(device)
# Out:
# cpu

# %% [markdown]
# # AWSmap pmmap

# %%
awsmap = pd.read_csv('./data/META/awsmap.csv')
pmmap = pd.read_csv('./data/META/pmmap.csv')

# %%
pmmap
# Out:
#    Location   Latitude   Longitude  \
# 0       아름동  36.512252  127.246789
# 1       신흥동  36.592887  127.292550
# 2       노은동  36.368242  127.318498
# 3       문창동  36.317215  127.437825
# 4       읍내동  36.372388  127.417714
# 5       정림동  36.304442  127.366742
# 6        공주  36.446951  127.119209
# 7        논산  36.199217  127.087021
# 8      대천2동  36.353148  126.589735
# 9       독곶리  36.987579  126.391672
# 10      동문동  36.780158  126.455197
# 11      모종동  36.782700  127.014610
# 12      신방동  36.782355  127.120506
# 13      예산군  36.677398  126.848918
# 14      이원면  36.869719  126.280501
# 15      홍성읍  36.597673  126.655087
# 16      성성동  36.840313  127.141777
#
#                                        Description
# 0              세종특별자치시 보듬3로 114 아름동커뮤니티센터 옥상 (아름동)
# 1          세종 조치원읍 군청로 87-16(신흥동) 세종특별자치시 조치원청사 옥상
# 2   대전 유성구 노은동로 87번길 89(노은1동 주민센터) 노은1동 주민센터 3층 옥상
# 3             대전 중구 보문로 20번길 38(문창동 주민센터) 문창동 주민센터
# 4            대전 대덕구 대전로 1331번길 75(태아산업(주)) 태아산업(주)
# 5                 대전 서구 정림동로 10(정림동 주민센터) 정림동 주민센터
# 6                          충남 공주시 봉황로 1 (공주시의회 옥상)
# 7             충남 논산시 시민로 389 (취암/부창동 행정복지센터 2층 옥상)
# 8                 충남 보령시 중앙로 142-16 (대천2동 주민센터 옥상)
# 9     충남 서산시 대산읍 평신1로(독곶리) 한국수자원공사 대산산업용수센터 저수동 옥상
# 10                  충청남도 서산시 중앙로 38-1 서산초등학교 (동문동)
# 11                          충남 아산시 모종동 573-2 보건소옥상
# 12     충남 천안시 동남구 천안천변길 127 천안시 맑은물사업소 하수처리장 (신방동)
# 13                 충남 예산군 예산읍 신흥길 63 (다목적 노인회관 옥상)
# 14             충남 태안군 이원면 분지길 14 (이원면사무소 1층 나동 옥상)
# 15          충남 홍성군 홍성읍 내포로 136번길 29 (느티나무 어린이집 옥상)
# 16                             충남 천안시 서북구 성성동 1-70

# %%
awsmap
# Out:
#    Location  Latitude  Longitude                           Description
# 0       오월드   36.2913   127.3959          대전광역시 중구사정공원로 70 오월드 내 플라워랜드
# 1        세천   36.3402   127.4938                    대전광역시 동구세천동 63-1
# 2        장동   36.4135   127.4382                   대전광역시 대덕구장동 360-2
# 3      세종고운   36.5315   127.2406                   세종특별자치시 고운동산 25번지
# 4      세종금남   36.4585   127.2688               세종특별자치시 시군구금남면 성덕리 77-3
# 5      세종연서   36.5667   127.2806                세종특별자치시 연서면봉암리 196-1
# 6      세종전의   36.6908   127.2005      세종특별자치시 전의면읍내리 5-1번지(전의생활체육공원)
# 7     북격렬비도   36.6254   125.5595          충청남도 태안군근흥면 가의도리산 27(북격렬비도)
# 8        호도   36.3012   126.2663                 충청남도 보령시오천면 녹도리 388-5
# 9        대산   37.0106   126.3881  충청남도 서산시대산읍 대죽리산95-1 (5304부대 대산방공진지)
# 10       홍북   36.6277   126.6451       충청남도 홍성군홍북면 상하리산91(1789부대 4대대)
# 11     홍성죽도   36.5200   126.4424                  충청남도 홍성군서부면 죽도리 33-1
# 12       공주   36.4828   127.1365         충청남도 공주시금흥동 산 21번지(공주예비군 훈련장)
# 13       서천   36.0625   126.7041         충청남도 서천군마서면 계동리 76-1서천군농업기술센터
# 14       논산   36.2116   127.1082                   충청남도 논산시덕지동 43-29
# 15       당진   36.8894   126.6174          충청남도 당진시채운동 363-23(당진예비군훈련장)
# 16       성거   36.8782   127.1561          충청남도 천안시서북구 성거읍봉주로 75(서북구청)
# 17       청양   36.4237   126.7791      충청남도 청양군청양읍 구봉로1026-84 청양농업기술센터
# 18       태안   36.7585   126.2964           충청남도 태안군태안읍 백화로49(태안초등학교)
# 19       예산   36.7421   126.8144       충청남도 예산군신암면 오신로852(예산군농업기술센터)
# 20       유구   36.5407   126.9336                충청남도 공주시유구읍 만천리500번지
# 21       정안   36.5511   127.0938                충청남도 공주시정안면 평정리284-5
# 22       아산   36.8458   126.8654     충청남도 아산시인주면 현대로1077(현대자동차㈜ 아산공장)
# 23       양화   36.1319   126.8602           충청남도 부여군양화면 충절로267-6 양화중학교
# 24       계룡   36.3132   127.2407       충청남도 계룡시신도안면 사서함 501-328호 공군기상단
# 25      춘장대   36.1741   126.5285                충청남도 서천군 서면 부사로 289부사교
# 26      대천항   36.3244   126.5021             충청남도 보령시신흑동 산 205155레이더기지
# 27       안도   36.9587   126.1683               충청남도 태안군원북면 방갈리산240번지
# 28       옹도   36.6476   126.0093                 충청남도 태안군근흥면 가의도리 산510
# 29       정산   36.3862   126.9565         충청남도 청양군정산면 학암리 19-2(축산기술연구소)

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(awsmap['Latitude'], awsmap['Longitude'])
plt.scatter(pmmap['Latitude'], pmmap['Longitude'])
plt.show()

# %% [markdown]
# ## Calculate distance

# %%
pm_cood = pmmap[['Location','Latitude','Longitude']]
aws_cood = awsmap[['Location','Latitude','Longitude']]

# %%
distance_list = []
location_list = []
for i in range(len(pm_cood)):
    min_distance = 1000000000
    location = None
    pm_lat = pm_cood['Latitude'][i]
    pm_lon = pm_cood['Longitude'][i]
    for j in range(len(aws_cood)):
        aws_lat = aws_cood['Latitude'][j]
        aws_lon = aws_cood['Longitude'][j]
        distance = math.sqrt((pm_lat-aws_lat)**2 + (pm_lon-aws_lon)**2)
        if min_distance > distance:
            min_distance = distance
            location = aws_cood['Location'][j]
    distance_list.append(min_distance)
    location_list.append(location)

# %%
print(location_list)
# Out:
# ['세종고운', '세종연서', '계룡', '오월드', '장동', '오월드', '공주', '논산', '대천항', '대산', '태안', '아산', '성거', '예산', '태안', '홍북', '성거']

# %% [markdown]
# # Concatenate PM and AWS

# %%
pm_csv_list = sorted(glob.glob('./data/TRAIN/*'))
pm_csv_list
# Out:
# ['./data/TRAIN/공주.csv',
#  './data/TRAIN/노은동.csv',
#  './data/TRAIN/논산.csv',
#  './data/TRAIN/대천2동.csv',
#  './data/TRAIN/독곶리.csv',
#  './data/TRAIN/동문동.csv',
#  './data/TRAIN/모종동.csv',
#  './data/TRAIN/문창동.csv',
#  './data/TRAIN/성성동.csv',
#  './data/TRAIN/신방동.csv',
#  './data/TRAIN/신흥동.csv',
#  './data/TRAIN/아름동.csv',
#  './data/TRAIN/예산군.csv',
#  './data/TRAIN/읍내동.csv',
#  './data/TRAIN/이원면.csv',
#  './data/TRAIN/정림동.csv',
#  './data/TRAIN/홍성읍.csv']

# %%
aws_basepath = './data/TRAIN_AWS/'
data = []
for idx, pm_path in enumerate(pm_csv_list):
    aws_path = './data/TRAIN_AWS/'+location_list[idx]+'.csv'
    pm_data = pd.read_csv(pm_path)
    aws_data = pd.read_csv(aws_path)
    #print(pm_data)
    #print(aws_data)
    aws_data['PM2.5'] = pm_data['PM2.5']
    time = []
    for i in range(len(aws_data)):
        time.append(datetime.datetime(2010+aws_data['연도'][i], int(aws_data['일시'][0][0:2]), 
                                             int(aws_data['일시'][i][3:5]), int(aws_data['일시'][i][6:8]), int(aws_data['일시'][i][9:])))
    aws_data['time'] = time
    aws_data['기온(°C)'].interpolate(method='cubic', inplace=True)
    aws_data['풍향(deg)'].interpolate(method='cubic', inplace=True)
    aws_data['풍속(m/s)'].interpolate(method='cubic', inplace=True)
    aws_data['강수량(mm)'].interpolate(method='cubic', inplace=True)
    aws_data['습도(%)'].interpolate(method='cubic', inplace=True)
    aws_data['PM2.5'].interpolate(method='cubic', inplace=True)
    
    aws_data.dropna(axis=0,inplace=True)
    
    aws_data.drop(['연도', '일시', '지점'], axis=1, inplace=True)
    
    
    aws_data = aws_data[['time','기온(°C)','풍향(deg)','풍속(m/s)','강수량(mm)','습도(%)','PM2.5']]
    #print(aws_data.describe())
    data.append(aws_data)

    #print(aws_data)
# Out:
#              기온(°C)       풍향(deg)       풍속(m/s)       강수량(mm)         습도(%)  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean       0.579297      0.391206      0.035396      0.001782      0.696283
# std        0.164991      0.325173      0.028738      0.014081      0.219401
# min        0.083728     -2.177995     -0.052748     -0.005819      0.043000
# 25%        0.448657      0.092778      0.015345      0.000000      0.537000
# 50%        0.589258      0.341111      0.028133      0.000000      0.719000
# 50%        0.595577      0.525000      0.038363      0.000000      0.749000
# 75%        0.725118      0.664167      0.058824      0.000000      0.894000
# max        0.971564     12.549651      0.355499      0.579545      1.448299
#
#               PM2.5
# count  35064.000000
# mean       0.088220
# std        0.074441
# min       -0.410534
# 25%        0.040000
# 50%        0.072000
# 75%        0.116000
# max        0.725310
#              기온(°C)       풍향(deg)       풍속(m/s)       강수량(mm)         습도(%)  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean       0.582408      0.459512      0.044323      0.002200      0.744164
# std        0.156068      0.353669      0.033624      0.024221      0.183943
# min        0.115324     -2.819169     -0.100162     -0.029386     -0.125984
# 25%        0.456556      0.143611      0.017903      0.000000      0.614000
# 50%        0.587678      0.429128      0.040921      0.000000      0.766000
# 75%        0.714060      0.819722      0.063939      0.000000      0.911000
# max        1.009305      2.929611      0.347826      0.864605      1.372953
#
#               PM2.5
# count  35064.000000
# mean       0.070128
# std        0.067379
# min       -0.512480
# 25%        0.032000
# 50%        0.056000
# 75%        0.088000
# max        0.812000
#              기온(°C)       풍향(deg)       풍속(m/s)       강수량(mm)         습도(%)  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean       0.578867      0.572542      0.050131      0.001636      0.733434
# std        0.174462      1.410818      0.071952      0.013059      0.309641
# min        0.086888     -2.423711     -0.112000     -0.023316     -3.638619
# 25%        0.445498      0.243333      0.017903      0.000000      0.598000
# 50%        0.587663      0.471389      0.040921      0.000000      0.770000
# 75%        0.710900      0.770278      0.066496      0.000000      0.968000
# max        1.837479     24.203380      1.061538      0.676136      1.147127
#
#               PM2.5
# count  35064.000000
# mean       0.069962
# std        0.057777
# min       -0.178912
# 25%        0.032000
# 50%        0.060000
# 75%        0.092000
# max        0.776000
#              기온(°C)       풍향(deg)       풍속(m/s)       강수량(mm)         습도(%)  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean       0.581337      0.368458      0.021612      0.001490      0.738386
# std        0.172384      0.409133      0.019955      0.012777      0.215197
# min        0.077409     -4.238233     -0.039718     -0.023664      0.105000
# 25%        0.443918      0.000000      0.007673      0.000000      0.575000
# 50%        0.590837      0.209583      0.017903      0.000000      0.772000
# 75%        0.725118      0.673889      0.030691      0.000000      0.955000
# max        0.998420      5.329514      0.235294      0.579545      1.903490
#
#               PM2.5
# count  35064.000000
# mean       0.098543
# std        0.085289
# min       -0.061222
# 25%        0.044000
# 50%        0.076000
# 75%        0.124000
# max        0.944986

# %%
for i in range(len(data)):
    print(data[i].isnull().sum())
# Out:
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64
# time       0
# 기온(°C)     0
# 풍향(deg)    0
# 풍속(m/s)    0
# 강수량(mm)    0
# 습도(%)      0
# PM2.5      0
# dtype: int64

# %%
def make_3d(df):
    df = df.drop('time',axis=1)
    train_x = []
    train_y = []
    val_x = []
    val_y = []
    for i in range(len(df)-INPUT_TIMESTEP-OUTPUT_TIMESTEP+1):
        if i < 30000:
            train_x.append(np.array((df[:][i:i+INPUT_TIMESTEP])))
            #print("X")
            #print(df[:][i:i+INPUT_TIMESTEP])
            train_y.append(np.array(df['PM2.5'][i+INPUT_TIMESTEP:i+INPUT_TIMESTEP+OUTPUT_TIMESTEP]))
            #print("Y")
            #print(df['PM2.5'][i+INPUT_TIMESTEP:i+INPUT_TIMESTEP+OUTPUT_TIMESTEP])
        else:
            val_x.append(np.array((df[:][i:i+INPUT_TIMESTEP])))
            #print("X")
            #print(df[:][i:i+INPUT_TIMESTEP])
            val_y.append(np.array(df['PM2.5'][i+INPUT_TIMESTEP:i+INPUT_TIMESTEP+OUTPUT_TIMESTEP]))
    return train_x, train_y, val_x, val_y

# %%
train_x_before_tensor = []
train_y_before_tensor = []
val_x_before_tensor = []
val_y_before_tensor = []
for i in range(len(data)):
    train_x, train_y, val_x, val_y = make_3d(data[i])
    train_x_before_tensor.extend(train_x)
    train_y_before_tensor.extend(train_y)
    val_x_before_tensor.extend(val_x)
    val_y_before_tensor.extend(val_y)

# %%
len(train_x_before_tensor)
# Out:
# 510000

# %%
train_x_tensor = torch.tensor(train_x_before_tensor)
train_y_tensor = torch.tensor(train_y_before_tensor).reshape(-1,OUTPUT_TIMESTEP,1)
val_x_tensor = torch.tensor(val_x_before_tensor)
val_y_tensor = torch.tensor(val_y_before_tensor).reshape(-1,OUTPUT_TIMESTEP,1)
print(train_x_tensor.shape)
print(train_y_tensor.shape)
print(val_x_tensor.shape)
print(val_y_tensor.shape)
# Out:
# torch.Size([510000, 48, 6])
# torch.Size([510000, 72, 1])
# torch.Size([84042, 48, 6])
# torch.Size([84042, 72, 1])

# %%
class MyDataset(Dataset):
    def __init__(self, origin_x, origin_y):
        self.data = origin_x
        self.target = origin_y
        
    def __getitem__(self, index):
        self.x = self.data[index]
        self.y = self.target[index]
        return self.x, self.y

    def __len__(self):
        return len(self.data)

#Pytorch를 사용하기 위해 custom dataset 구성해줌

# %%
train_dataset = MyDataset(train_x_tensor, train_y_tensor)
train_loader = DataLoader(train_dataset, batch_size=BS, shuffle=False)
val_dataset = MyDataset(val_x_tensor, val_y_tensor)
val_loader = DataLoader(val_dataset, batch_size=BS, shuffle=False)

# %%
it = iter(train_loader)
print(next(it)[0].shape)
print(next(it)[1].shape)
input_size = next(it)[0].shape[2]
# Out:
# torch.Size([64, 48, 6])
# torch.Size([64, 72, 1])

# %%
#Reference : https://doheon.github.io/%EC%BD%94%EB%93%9C%EA%B5%AC%ED%98%84/time-series/ci-3.lstm-post/
class Encoder(nn.Module):
    def __init__(self, input_size):
        super(Encoder, self).__init__()
        self.input_size = input_size
        self.lstm = nn.LSTM(input_size = input_size, hidden_size = 128, num_layers = 1, batch_first=True)
        self.weight_init()
        
    def forward(self, x):
        output, hidden = self.lstm(x)
        return output, hidden
    
    def weight_init(self):
        #Reference : https://www.kaggle.com/code/junkoda/pytorch-lstm-with-tensorflow-like-initialization
        """
        Tensorflow/Keras-like initialization
        """
        for name, p in self.named_parameters():
            if 'lstm' in name:
                if 'weight_ih' in name:
                    nn.init.xavier_uniform_(p.data)
                elif 'weight_hh' in name:
                    nn.init.orthogonal_(p.data)
                elif 'bias_ih' in name:
                    p.data.fill_(0)
                    # Set forget-gate bias to 1
                    n = p.size(0)
                    p.data[(n // 4):(n // 2)].fill_(1)
                elif 'bias_hh' in name:
                    p.data.fill_(0)
                    
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal(m.weight)
                nn.init.zeros_(m.bias)

# %%
class Decoder(nn.Module):
    def __init__(self, input_size):
        super(Decoder, self).__init__()
        self.input_size = input_size
        self.lstm = nn.LSTM(input_size = 1, hidden_size = 128, num_layers = 1, batch_first=True)
        self.linear = nn.Linear(128, 1)           
        self.weight_init()
        
    def forward(self, x, encoder_hidden_states):
        x = x.unsqueeze(1)
        #print(x.shape)
        lstm_out, hidden = self.lstm(x, encoder_hidden_states)
        output = self.linear(lstm_out)
        
        
        return output, hidden
    
    def weight_init(self):
        #Reference : https://www.kaggle.com/code/junkoda/pytorch-lstm-with-tensorflow-like-initialization
        """
        Tensorflow/Keras-like initialization
        """
        for name, p in self.named_parameters():
            if 'lstm' in name:
                if 'weight_ih' in name:
                    nn.init.xavier_uniform_(p.data)
                elif 'weight_hh' in name:
                    nn.init.orthogonal_(p.data)
                elif 'bias_ih' in name:
                    p.data.fill_(0)
                    # Set forget-gate bias to 1
                    n = p.size(0)
                    p.data[(n // 4):(n // 2)].fill_(1)
                elif 'bias_hh' in name:
                    p.data.fill_(0)
                    
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal(m.weight)
                nn.init.zeros_(m.bias)

# %%
class Seq2Seq_model(nn.Module):
    def __init__(self, input_size):
        super(Seq2Seq_model, self).__init__()

        self.input_size = input_size

        self.encoder = Encoder(input_size = input_size)
        self.decoder = Decoder(input_size = input_size)

    def forward(self, x, y):
        batch_size = x.shape[0]
        input_size = x.shape[2]

        outputs = torch.zeros(batch_size, OUTPUT_TIMESTEP,1).to(device)

        _, hidden = self.encoder(x)
        decoder_input = x[:,-1, -1]
        decoder_input = decoder_input.unsqueeze(-1)
        
        for t in range(OUTPUT_TIMESTEP): 
            #print("Decoder Input : "+str(decoder_input.shape))
            out, hidden = self.decoder(decoder_input, hidden)
            #print("out shape : "+ str(out.shape))
            out =  out.squeeze(1)
            #print("out shape after squeeze: "+ str(out.shape))
            if random.random() < TEACHER_FORCING_RATIO:
                decoder_input = y[:, t, :]
            else:
                decoder_input = out
            outputs[:,t,:] = out
            #print(outputs.shape)

        return outputs
    
    def predict(self, x):
        batch_size = x.shape[0]
        input_size = x.shape[2]

        outputs = torch.zeros(batch_size, OUTPUT_TIMESTEP,1)

        _, hidden = self.encoder(x)
        decoder_input = x[:,-1, -1]
        decoder_input = decoder_input.unsqueeze(-1)
        
        for t in range(OUTPUT_TIMESTEP): 
            #print("Decoder Input : "+str(decoder_input.shape))
            out, hidden = self.decoder(decoder_input, hidden)
            #print("out shape : "+ str(out.shape))
            out =  out.squeeze(1)
            #print("out shape after squeeze: "+ str(out.shape))
            decoder_input = out
            outputs[:,t,:] = out
            #print(outputs.shape)

        return outputs

# %%
class Trainer():
    def __init__(self, model, optimizer, train_loader, val_loader, scheduler, device):
        self.model = model
        self.optimizer = optimizer
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.scheduler = scheduler
        self.device = device
        # Loss Function
        self.criterion = nn.MSELoss().to(self.device)
        
    def fit(self):
        self.model.to(self.device)
        best_loss = 1000000000
        for epoch in range(EPOCHS):
            self.model.train()
            train_loss = []
            i = 1
            for x, y in tqdm(self.train_loader):
                x = x.float().to(self.device)
                y = y.float().to(self.device)
                self.optimizer.zero_grad()
                output = self.model(x, y).to(device)
                output = output.squeeze(-1)
                y = y.squeeze(-1)
                torch.nn.utils.clip_grad_norm_(model.parameters(), 5)
                loss = self.criterion(y,output)
                loss.backward()
                self.optimizer.step()
                train_loss.append(loss.item())
                i=i+1
                
            val_loss = self.validation(self.model)
            
            mean_train_loss = np.mean(train_loss)
            
            print(f'Epoch : [{epoch+1}] Train loss : [{mean_train_loss}]\nVal Loss : [{val_loss}]\n')
            
            self.scheduler.step(val_loss)
            
            if best_loss > val_loss:
                best_loss = val_loss
                torch.save(self.model, './' + MODEL_NAME+'.pth')
                print("Save Model~_~")
                
        print(best_loss)
           
    def validation(self, eval_model):
        eval_model.eval()
        val_loss = []
        mse_list = []
        with torch.no_grad():
            for x, y in iter(self.val_loader):
                x = x.float().to(self.device)
                y = y.float().to(self.device)
                output = eval_model.predict(x)
                output = output.squeeze(-1)
                y = y.squeeze(-1)
                loss = self.criterion(y,output)
                val_loss.append(loss.item())
                
        return np.mean(val_loss)

# %%
#Train model
gc.collect()

seed_everything(SEED)
model = Seq2Seq_model(input_size).to(device)
#Using AdamW Optimizer
optimizer = torch.optim.AdamW(params = model.parameters(), lr = LR,weight_decay=1e-1)#Opimizer : AdamW
#Using Learning Rate Scheduler (ReduceLROnPlateau)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, threshold = 1e-8, threshold_mode='abs', min_lr=1e-8, verbose=True)
trainer = Trainer(model, optimizer, train_loader, val_loader, scheduler, device)
#trainer 객체 생성
trainer.fit()
# Out:
# /var/folders/wh/7nbvd7tj6j99g3z6knc92ccc0000gn/T/ipykernel_28561/1272543324.py:39: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight)
# 100%|███████████████████████████████████████| 7969/7969 [09:17<00:00, 14.30it/s]
# Epoch : [1] Train loss : [0.0030332824102041267]
# Val Loss : [0.004706514873231362]
# 100%|███████████████████████████████████████| 7969/7969 [09:17<00:00, 14.30it/s]
# Epoch : [2] Train loss : [0.006122978756605437]
# Val Loss : [0.0038102054530368408]
# 100%|███████████████████████████████████████| 7969/7969 [09:15<00:00, 14.34it/s]
# Epoch : [3] Train loss : [0.004168658587617383]
# Val Loss : [0.003810718909635661]
# 100%|███████████████████████████████████████| 7969/7969 [09:21<00:00, 14.19it/s]
# Epoch : [4] Train loss : [0.0029366660626531315]
# Val Loss : [0.0037996082430927095]
# 100%|███████████████████████████████████████| 7969/7969 [09:21<00:00, 14.18it/s]
# Epoch : [5] Train loss : [0.004542695991592887]
# Val Loss : [0.0038048125184693055]
# 100%|███████████████████████████████████████| 7969/7969 [09:22<00:00, 14.17it/s]
# Epoch : [6] Train loss : [0.007379403934380791]
# Val Loss : [0.004341077008033016]
#  15%|█████▋                                 | 1168/7969 [01:22<07:53, 14.36it/s]

# %%
pretrained_model = torch.load('./' + MODEL_NAME+'.pth')
pretrained_model = pretrained_model.to(device)
pretrained_model.eval()
summary(pretrained_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Seq2Seq_model                            --
# ├─Encoder: 1-1                           --
# │    └─LSTM: 2-1                         69,632
# ├─Decoder: 1-2                           --
# │    └─LSTM: 2-2                         67,072
# │    └─Linear: 2-3                       129
# =================================================================
# Total params: 136,833
# Trainable params: 136,833
# Non-trainable params: 0
# =================================================================

# %%
test_pm_csv_list = sorted(glob.glob('./data/TEST_INPUT/*'))
test_pm_csv_list
# Out:
# ['./data/TEST_INPUT/공주.csv',
#  './data/TEST_INPUT/노은동.csv',
#  './data/TEST_INPUT/논산.csv',
#  './data/TEST_INPUT/대천2동.csv',
#  './data/TEST_INPUT/독곶리.csv',
#  './data/TEST_INPUT/동문동.csv',
#  './data/TEST_INPUT/모종동.csv',
#  './data/TEST_INPUT/문창동.csv',
#  './data/TEST_INPUT/성성동.csv',
#  './data/TEST_INPUT/신방동.csv',
#  './data/TEST_INPUT/신흥동.csv',
#  './data/TEST_INPUT/아름동.csv',
#  './data/TEST_INPUT/예산군.csv',
#  './data/TEST_INPUT/읍내동.csv',
#  './data/TEST_INPUT/이원면.csv',
#  './data/TEST_INPUT/정림동.csv',
#  './data/TEST_INPUT/홍성읍.csv']

# %%
test_data = []
for idx, pm_path in enumerate(test_pm_csv_list):
    aws_path = './data/TEST_AWS/'+location_list[idx]+'.csv'
    pm_data = pd.read_csv(pm_path)
    aws_data = pd.read_csv(aws_path)
    #print(pm_data)
    #print(aws_data)
    aws_data['PM2.5'] = pm_data['PM2.5']
    #print(aws_data[:][:50])
    time = []
    for i in range(len(aws_data)):
        time.append(datetime.datetime(2010+aws_data['연도'][i], int(aws_data['일시'][0][0:2]), 
                                             int(aws_data['일시'][i][3:5]), int(aws_data['일시'][i][6:8]), int(aws_data['일시'][i][9:])))
    aws_data['time'] = time
    
    aws_data.dropna(axis=0,inplace=True)
    aws_data.reset_index(drop=True, inplace=True)
    aws_data.drop(['연도', '일시', '지점'], axis=1, inplace=True)
    
    
    aws_data = aws_data[['time','기온(°C)','풍향(deg)','풍속(m/s)','강수량(mm)','습도(%)','PM2.5']]
    aws_data = aws_data[:][:-48]
    test_data.append(aws_data)
    print(aws_data)
    #print(aws_data)
# Out:
#                     time    기온(°C)   풍향(deg)   풍속(m/s)  강수량(mm)  습도(%)  PM2.5
# 0    2014-01-01 00:00:00  0.232227  0.091944  0.012788      0.0  0.683  0.060
# 1    2014-01-01 01:00:00  0.225908  0.127222  0.012788      0.0  0.633  0.064
# 2    2014-01-01 02:00:00  0.222749  0.000000  0.002558      0.0  0.630  0.072
# 3    2014-01-01 03:00:00  0.211690  0.000000  0.000000      0.0  0.641  0.064
# 4    2014-01-01 04:00:00  0.218009  0.000000  0.005115      0.0  0.652  0.056
# ...                  ...       ...       ...       ...      ...    ...    ...
# 3067 2014-01-13 19:00:00  0.491311  0.528056  0.020460      0.0  0.768  0.116
# 3068 2014-01-13 20:00:00  0.483412  0.563333  0.025575      0.0  0.805  0.132
# 3069 2014-01-13 21:00:00  0.475513  0.585000  0.012788      0.0  0.854  0.128
# 3070 2014-01-13 22:00:00  0.466035  0.000000  0.002558      0.0  0.883  0.124
# 3071 2014-01-13 23:00:00  0.451817  0.559444  0.015345      0.0  0.925  0.132
#
# [3072 rows x 7 columns]
#                     time    기온(°C)   풍향(deg)   풍속(m/s)  강수량(mm)  습도(%)  PM2.5
# 0    2014-01-01 00:00:00  0.214850  0.104167  0.025575      0.0  0.564  0.040
# 1    2014-01-01 01:00:00  0.197472  0.937222  0.012788      0.0  0.559  0.056
# 3071 2014-01-13 23:00:00  0.461295  0.783056  0.025575      0.0  0.982  0.120
#
# [3072 rows x 7 columns]
#                     time    기온(°C)   풍향(deg)   풍속(m/s)  강수량(mm)  습도(%)  PM2.5
# 0    2014-01-01 00:00:00  0.225908  0.051667  0.025575      0.0  0.548  0.056
# 1    2014-01-01 01:00:00  0.218009  0.000000  0.005115      0.0  0.570  0.056
# 2    2014-01-01 02:00:00  0.206951  0.000000  0.005115      0.0  0.631  0.072
# 3    2014-01-01 03:00:00  0.200632  0.632222  0.015345      0.0  0.675  0.072
# 4    2014-01-01 04:00:00  0.189573  0.000000  0.002558      0.0  0.705  0.080
# ...                  ...       ...       ...       ...      ...    ...    ...
# 3067 2014-01-13 19:00:00  0.494471  0.000000  0.000000      0.0  0.816  0.160
# 3068 2014-01-13 20:00:00  0.481833  0.000000  0.000000      0.0  0.839  0.172
# 3069 2014-01-13 21:00:00  0.469194  0.000000  0.002558      0.0  0.874  0.160
# 3070 2014-01-13 22:00:00  0.467615  0.000000  0.000000      0.0  0.873  0.156
# 3071 2014-01-13 23:00:00  0.454976  0.000000  0.000000      0.0  0.919  0.140
#
# [3072 rows x 7 columns]

# %%
def make_3d_test(df):
    df = df.drop('time',axis=1)
    test_x = np.array(df)
    test_x = test_x.reshape(-1,48,6)
    test_x = torch.tensor(test_x)     
    return test_x

# %%
class make_test_dataset(Dataset):
    def __init__(self, origin_x):
        self.data = origin_x
        
    def __getitem__(self, index):
        self.x = self.data[index]
        return self.x

    def __len__(self):
        return len(self.data)

#Pytorch를 사용하기 위해 custom dataset 구성해줌

# %%
test_tensor_list =[]
for i in range(len(test_data)):
    test_tensor_list.append(make_3d_test(test_data[i]))
    print(test_tensor_list[0].shape)

test_tensor = torch.cat(test_tensor_list)
print(test_tensor.shape)
# Out:
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([64, 48, 6])
# torch.Size([1088, 48, 6])

# %%
test_dataset = make_test_dataset(test_tensor)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
pretrained_model.eval()
pred = []
with torch.no_grad():
    for x in iter(test_loader):
        x = x.float().to(device)
        output = pretrained_model.predict(x)
        output = output.squeeze(-1).squeeze(0)
        #print(output.shape)
        #print(output.shape)
        origin = x.squeeze(0)[:,-1]
        #print(origin.shape)
        #kk = torch.cat([origin,output], dim=0)
        #plt.plot(kk)
        #plt.show()
        #pm = x[:]
        pred.extend(output.cpu().detach().tolist())
print(len(pred))
# Out:
# 78336

# %%
submit = pd.read_csv('./data/answer_sample.csv')
submit['PM2.5'] = pred
submit.to_csv(f'./LSTM_Seq2Seq_ver_1.csv')
